# %%
import os, glob
NameList = sorted(glob.glob('./FolderNames/Names*'))
FileList = sorted(glob.glob('./FolderNames/File*'))

Offices = ['765AS','SD','milion']
OfficeNames = {'765AS':'アイドルマスター','milion':'ミリオンライブ', 'SD':'シンデレラガールズ'}
filnums = {}
TagNames = []
FolNames = []
idolcon = []
lateNum = 0

for num in range(len(NameList)):
    with open(NameList[num] ,'r', encoding="utf-8") as t:
        TagName = t.readlines()
    with open(FileList[num], 'r', encoding="utf-8") as f:
        FolName = f.readlines()
    idolcon.append(len(TagName))
    imgpass = './static/images/' + Offices[num] +'/'
    for count in range(len(TagName)):
        TagNames.append(TagName[count].replace("\n",""))
        FolNames.append(FolName[count].replace("\n",""))
        filnums[FolNames[-1]] = os.listdir(imgpass+FolNames[-1])
        #TagNames[count+lateNum] = TagName[count].replace("\n", "")
        #FolNames[count+lateNum] = FolName[count].replace("\n", "")
        #filnums[FolNames[count+lateNum]]   = os.listdir(imgpass+FolNames[count+lateNum]+'/')
    lateNum += (count+1)

# %%
TagNames
# Out:
# [13,
#  '天海春香',
#  'AmamiHaruka',
#  '如月千早',
#  'KisaragiChihaya',
#  '四条貴音',
#  'ShijyoTakane',
#  '三浦あずさ',
#  'MiuraAzusa',
#  '水瀬伊織',
#  'MinaseIori',
#  '我那覇響',
#  'GanahaHibiki',
#  '菊地真',
#  'KikutiMakoto',
#  '高槻やよい',
#  'TakatsukiYayoi',
#  '秋月律子',
#  'AkitsukiRitsuko',
#  '萩原雪歩',
#  'HagiwaraYukiho',
#  '双海亜美',
#  'FutamiAmi',
#  '双海真美',
#  'FutamiMami',
#  '星井美希',
#  'HoshiMiki',
#  185,
#  '相川千夏',
#  'AikawaChinatsu',
#  '愛野渚',
#  'AinoNagisa',
#  '相原雪乃',
#  'AiharaYukino',
#  '相葉夕美',
#  'AibaYumi',
#  '赤城みりあ',
#  'AkagiMiria',
#  '赤西瑛梨華',
#  'AkanishiEriki',
#  '浅野風香',
#  'AsanoHuka',
#  '浅利七海',
#  'AsariNanami',
#  'アナスタシア',
#  'Anastacia',
#  '安部菜々',
#  'AbeNana',
#  '綾瀬穂乃香',
#  'AyaseHonoka',
#  '荒木比奈',
#  'ArakiHina',
#  '有浦柑奈',
#  'AriuraKanna',
#  '安斎都',
#  'AnzaiMiyako',
#  '五十嵐響子',
#  'IgarashiKyoko',
#  '池袋晶葉',
#  'IkebukuroAkiha',
#  '伊集院惠',
#  'IjuinMegumi',
#  '一ノ瀬志希',
#  'IchinoseShiki',
#  '市原仁奈',
#  'IchiharaNina',
#  'イヴ・サンタクロース',
#  'YveSantaclaus',
#  '今井加奈',
#  'ImaiKana',
#  '井村雪菜',
#  'ImuraSetsuna',
#  '上田鈴帆',
#  'UedaSuzuho',
#  '氏家むつみ',
#  'UjiieMutsumi',
#  '梅木音葉',
#  'UmekiOtoha',
#  '江上椿',
#  'EgamiTsubaki',
#  '衛藤美紗希',
#  'EtoMisaki',
#  '海老原菜帆',
#  'EbiharaNaho',
#  '及川雫',
#  'OikawaShizuku',
#  '大石泉',
#  'OishiIzumi',
#  '太田優',
#  'OtaYou',
#  '大槻唯',
#  'OtsukiYui',
#  '大西由里子',
#  'OnishiYuriko',
#  '大沼くるみ',
#  'OnumaKurumi',
#  '大原みちる',
#  'OharaMichiru',
#  '岡崎泰葉',
#  'OkazakiYasuha',
#  '緒方智絵里',
#  'OgataChieri',
#  '奥山沙織',
#  'OkuyamaSaori',
#  '乙倉悠貴',
#  'OtokuraYuki',
#  '片桐早苗',
#  'KatagiriSanae',
#  '上条春菜',
#  'KamijoHaruna',
#  '神谷奈緒',
#  'KamiyaNao',
#  '川島瑞樹',
#  'KawashimaMizuki',
#  '神崎蘭子',
#  'KanzakiRanko',
#  '岸部彩華',
#  'KishibeAyaka',
#  '北川真尋',
#  'KitagawaMahiro',
#  '喜多日菜子',
#  'KitaHinako',
#  '喜多見柚',
#  'KitamiYuzu',
#  '木場真奈美',
#  'KibaManami',
#  '木村夏樹',
#  'KimuraNatsuki',
#  'キャシー・グラハム',
#  'CathyGraham',
#  '桐野アヤ',
#  'KirinoAya',
#  '桐生つかさ',
#  'KiryuTsukasa',
#  '日下部若葉',
#  'KusakabeWakaba',
#  '工藤忍',
#  'KudoShinobu',
#  'クラリス',
#  'Claris',
#  '栗原ネネ',
#  'KuriharaNene',
#  '黒川千秋',
#  'KurokawaChiaki',
#  'ケイト',
#  'Kate',
#  '古賀小春',
#  'KogaKoharu',
#  '輿水幸子',
#  'KoshimizuSachiko',
#  '小関麗奈',
#  'KosekiReina',
#  '小早川紗枝',
#  'KobayakawaSae',
#  '小日向美穂',
#  'KohinataMiho',
#  '小松伊吹',
#  'KomatsuIbuko',
#  '小室千奈美',
#  'KomuroChiNami',
#  '西園寺琴歌',
#  'SaionjiKotoka',
#  '斉藤洋子',
#  'SaitoYoko',
#  '冴島清美',
#  'SaejimaKiyomi',
#  '榊原里美',
#  'SakakibaraSatomi',
#  '鷺沢文香',
#  'SagisawaFumika',
#  '佐久間まゆ',
#  'SakumaMayu',
#  '櫻井桃華',
#  'SakuraiMomoka',
#  '佐々木千枝',
#  'SasakiChie',
#  '佐城雪美',
#  'SajoYukimi',
#  '佐藤心',
#  'SatoShin',
#  '沢田麻理菜',
#  'SawadaMarina',
#  '財前時子',
#  'ZaizenTokiko',
#  '椎名法子',
#  'ShiinaNoriko',
#  '塩見周子',
#  'ShiomiShuko',
#  '篠原礼',
#  'ShinoharaRei',
#  '渋谷凛',
#  'ShibuyaRin',
#  '島村卯月',
#  'ShimamuraUzuki',
#  '首藤葵',
#  'ShutoAoi',
#  '白菊ほたる',
#  'ShiragikuHotaru',
#  '白坂小梅',
#  'ShirasakaKoume',
#  '城ヶ崎美嘉',
#  'JogasakiMika',
#  '城ヶ崎莉嘉',
#  'JogasakiRika',
#  '杉坂海',
#  'SugisakaUmi',
#  '涼宮星花',
#  'Suzumiyaseika',
#  '関裕美',
#  'SekiHiromi',
#  '瀬名詩織',
#  'SenaShiori',
#  '千川ちひろ',
#  'SenkawaChihiro',
#  '仙崎恵磨',
#  'SenzakiEma',
#  '相馬夏美',
#  'SomaNatsumi',
#  '高垣楓',
#  'TakagakiKaede',
#  '高橋礼子',
#  'TakahashiReiko',
#  '鷹富士茄子',
#  'TakahujiKako',
#  '高峯のあ',
#  'TakamineNoa',
#  '高森藍子',
#  'TakamoriAiko',
#  '多田李衣菜',
#  'TadaRina',
#  '橘ありす',
#  'TachibanaArisu',
#  '月宮雅',
#  'TsukimiyaMiyabi',
#  '土屋亜子',
#  'TsuchiyaAko',
#  '東郷あい',
#  'TogoAi',
#  '十時愛梨',
#  'TotokiAiri',
#  'トレーナー',
#  'Trainer',
#  '道明寺歌鈴',
#  'DoumyojiKarin',
#  '中野有香',
#  'NakanoYuka',
#  '長富蓮実',
#  'NagatomiHasumi',
#  'ナターリア',
#  'Natalia',
#  '並木芽衣子',
#  'NamikiMeiko',
#  '成宮由愛',
#  'NarumiyaYume',
#  '南条光',
#  'NanjoHikaru',
#  '難波笑美',
#  'NambaEmi',
#  '西川保奈美',
#  'NishikawaHonami',
#  '西島櫂',
#  'NishijimaKai',
#  '新田美波',
#  'NittaMinami',
#  '二宮飛鳥',
#  'NinomiyaAsuka',
#  '丹羽仁美',
#  'NiwaHitomi',
#  '野々村そら',
#  'NonomuraSora',
#  '服部瞳子',
#  'HattoriToko',
#  '浜川愛結奈',
#  'HamakawaAyuna',
#  '浜口あやめ',
#  'HamaguchiAyame',
#  '早坂美玲',
#  'HayasakaMirei',
#  '速水奏',
#  'HayamiKanade',
#  '原田美世',
#  'HaradaMiyo',
#  '柊志乃',
#  'HiiragiShino',
#  '日野茜',
#  'HinoAkane',
#  '姫川友紀',
#  'HimekawaYuki',
#  '兵藤レナ',
#  'HyodoRena',
#  '福山舞',
#  'FukuyamaMai',
#  '藤居朋',
#  'FujiiTomo',
#  '藤本里奈',
#  'FujimotoRina',
#  '藤原肇',
#  'FujiwaraHajime',
#  '双葉杏',
#  'FutabaAnzu',
#  '古澤頼子',
#  'FurusawaYoriko',
#  'ヘレン',
#  'Helen',
#  '北条加蓮',
#  'HojoKaren',
#  '星輝子',
#  'HoshiShoko',
#  '堀裕子',
#  'HoriYuko',
#  '本田未央',
#  'HondaMio',
#  '前川みく',
#  'MaekawaMiku',
#  '槙原志保',
#  'MakiharaShiho',
#  '松尾千鶴',
#  'MatsuoChizuru',
#  '松永涼',
#  'MatsunagaRyo',
#  '松原早耶',
#  'MatsubaraSaya',
#  '松本沙理奈',
#  'MatsumotoSarina',
#  '松山久美子',
#  'MatsuyamaKumiko',
#  '的場梨沙',
#  'MatobaRisa',
#  '間中美里',
#  'ManakaMisato',
#  '真鍋いつき',
#  'ManabeItsuki',
#  '水木聖來',
#  'MizukiSeira',
#  '水野翠',
#  'MizunoMidori',
#  '水本ゆかり',
#  'MizumotoYukari',
#  '三船美優',
#  'MihuneMiyu',
#  '三村かな子',
#  'MimuraKanako',
#  '宮本フレデリカ',
#  'MiyamotoFrederica',
#  '三好紗南',
#  'MiyoshiSana',
#  '向井拓海',
#  'MukaiTakumi',
#  '棟方愛海',
#  'MunakataAtsumi',
#  '村上巴',
#  'MurakamiTomoe',
#  '村松さくら',
#  'MuramatsuSakura',
#  'メアリー・コクラン',
#  'MaryCochran',
#  '持田亜里沙',
#  'MochidaArisa',
#  '望月聖',
#  'MochizukiHijiri',
#  '桃井あずき',
#  'MomoiAzuki',
#  '森久保乃々',
#  'MorikuboNono',
#  '諸星きらり',
#  'MoroboshiKirari',
#  '楊菲菲',
#  'YanFeiFei',
#  '八神ﾏｷﾉ',
#  'YagamiMakino',
#  '矢口美羽',
#  'YaguchiMiu',
#  '柳清良',
#  'YanagiKiyora',
#  '柳瀬美由紀',
#  'YanaseMiyuki',
#  '大和亜季',
#  'YamatoAki',
#  '結城晴',
#  'YuukiHaru',
#  '遊佐こずえ',
#  'YusaKozue',
#  '横山千佳',
#  'YokoyamaChika',
#  '吉岡沙紀',
#  'YoshiokaSaki',
#  '依田芳乃',
#  'YoritaYoshino',
#  'ライラ',
#  'Laila',
#  '龍崎薫',
#  'RyuzakiKaoru',
#  '若林智香',
#  'WakabayashiTomoka',
#  '脇山珠美',
#  'WakiyamaTamami',
#  '和久井留美',
#  'WakuiRumi',
#  39,
#  '春日 未来',
#  'KasugaMirai',
#  '木下 ひなた',
#  'KinoshitaHinata',
#  'ジュリア',
#  'Julia',
#  '高山 紗代子',
#  'TakayamaSayoko',
#  '田中 琴葉',
#  'TanakaKotoba',
#  '天空橋 朋花',
#  'TenkubashiTomoka',
#  '箱崎 星梨花',
#  'HakozakiSerika',
#  '松田 亜利沙',
#  'MatsudaArisa',
#  '最上 静香',
#  'MogamiShizuka',
#  '望月 杏奈',
#  'MochizukiAnna',
#  '矢吹 可奈',
#  'YabukiKana',
#  'エミリー スチュアート',
#  'Emily',
#  '大神 環',
#  'OgamiTamaki',
#  '高坂 海美',
#  'KousakaUmi',
#  '北上 麗花',
#  'KitagamiReika',
#  '佐竹 美奈子',
#  'SatakeMinako',
#  '島原 エレナ',
#  'ShimabaraElena',
#  '永吉 昴',
#  'NagayoshiSubaru',
#  '野々原 茜',
#  'NonoharaAkane',
#  '馬場 このみ',
#  'BabaKonomi',
#  '福田 のり子',
#  'FukudaNoriko',
#  '舞浜 歩',
#  'MaihamaAyumi',
#  '真壁 瑞希',
#  'MakabeMizuki',
#  '百瀬 莉緒',
#  'MomoseRio',
#  '横山 奈緒',
#  'YokoyamaNao',
#  '伊吹 翼',
#  'IbukiTsubasa',
#  '北沢 志保',
#  'KitazawaShiho',
#  '篠宮 可憐',
#  'ShinomiyaKaren',
#  '周防 桃子',
#  'SuouMomoko',
#  '徳川 まつり',
#  'TokugawaMatsuri',
#  '所 恵美',
#  'TokorozawaEmi',
#  '豊川 風花',
#  'ToyokawaFuka',
#  '中谷 育',
#  'NakataniIku',
#  '七尾 百合子',
#  'NanaoYuriko',
#  '二階堂 千鶴',
#  'NikaidoChizuru',
#  '宮尾 美也',
#  'MiyaoMiya',
#  'ロコ',
#  'Loco',
#  '桜守 歌織',
#  'SakuramoriKaori',
#  '白石 紬',
#  'ShiraishiTsumugi']

# %%
FileList
# Out:
# ['./FolderNames/FileNamesSD.txt',
#  './FolderNames/FileNames765AS.txt',
#  './FolderNames/FileNamesmilion.txt']
